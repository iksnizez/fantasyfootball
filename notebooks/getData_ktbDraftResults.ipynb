# %%
##### importing custom modules from the projects folder
import sys
from pathlib import Path
# Add project root to sys.path
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT))
import modules.ktbFantasyFootball as ktbff
##### -------------------------------------------------
from datetime import date

##### PARAMS ######
league = 'nfl'
export = True
today = date.today()
season = 2025
week = 0   # WEEK DOESNT MATTER FOR THIS NOTEBOOK SINCE ITS ONLY DRAFT

league = ktbff.ktb(
    season = season,
    week = week,
    database_export = export, 
    store_locally = export
)

# %% [markdown]
# # draft results
# ##### !!!!**** need to update the input with team names used in draft

# %%
print('saving to db... ', league.database_export)
# Out:
# saving to db...  True

# %%
league.get_draft_results(
    nTeams = 12,
    database_table = 'ktbdrafts',
    map_team_id = {
        'Legette another baby':1,
        'Team Gomer':2,
        'DPD DannyDimes':3,
        'Poopstained Warriors':4,
        'JB got last in 23':5,
        'B Team':6,
        'Team Chaunce':7, 
        'Touchdown My Pants':8,
        'Big Baby Nate':9,
        'CeeDeez Nutz':10,
        'The Suavin Scoregasms':11,
        'free breece':12   
    }
)
# Out:
# successfully added data to ktbdrafts

# %%
league.draft_results
# Out:
#                   teamName season  pick  round  overallPick  \
# 0           DPD DannyDimes   2025     1      1            1
# 1             CeeDeez Nutz   2025     2      1            2
# 2    The Suavin Scoregasms   2025     3      1            3
# 3            Big Baby Nate   2025     4      1            4
# 4                   B Team   2025     5      1            5
# ..                     ...    ...   ...    ...          ...
# 163                 B Team   2025     8     14          164
# 164          Big Baby Nate   2025     9     14          165
# 165  The Suavin Scoregasms   2025    10     14          166
# 166           CeeDeez Nutz   2025    11     14          167
# 167         DPD DannyDimes   2025    12     14          168
#
#                     name playerTeam pos  teamId
# 0    Christian McCaffrey         SF  RB       3
# 1          Ja'Marr Chase        Cin  WR      10
# 2         Bijan Robinson        Atl  RB      11
# 3         Saquon Barkley        Phi  RB       9
# 4       Justin Jefferson        Min  WR       6
# ..                   ...        ...  ..     ...
# 163        Will Reichard        Min   K       6
# 164          C.J. Stroud        Hou  QB       9
# 165       Tyler Allgeier        Atl  RB      11
# 166           Tyler Bass        Buf   K      10
# 167         Cairo Santos        Chi   K       3
#
# [168 rows x 9 columns]
